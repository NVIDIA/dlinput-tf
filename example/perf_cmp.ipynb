# %%
for i in range(10):
    # !python3 perf_test.py -n 100
# Out:
# 2019-04-18 12:55:55.252855: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# WARNING:tensorflow:From /home/wendyh/.local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 2019-04-18 12:55:55.334756: I /tmp/pip-req-build-hlcrq7bf/zmq_ops/kernel/zmq_base.h:22] Connecting to zmq with address: tcp://127.0.0.1:7880
# 100 batches, 3200 samples
# 0.0531 s per batch, 0.00166 s per sample
# shapes: {('float16', 32, 224, 224, 3)}
# [0 1] mean=0.446 std=0.279 n=481689600
# rate 19.392602 samp/s throughput 1.87e+08 bytes/s
# ...

# %%
for i in range(10):
    # !./tensorcom/tensorstat -c 100 zsub://127.0.0.1:7880
# Out:
# zsub://127.0.0.1:7880
# 100 batches, 3200 samples
# 0.05 s per batch, 0.00156 s per sample
# shapes: {('float16', 32, 224, 224, 3)}
# [0 1] mean=0.446 std=0.279 n=481689600
# rate 20.302819 samp/s throughput 1.96e+08 bytes/s
# zsub://127.0.0.1:7880
# 100 batches, 3200 samples
# 0.05 s per batch, 0.00156 s per sample
# shapes: {('float16', 32, 224, 224, 3)}
# [0 1] mean=0.446 std=0.279 n=481689600
# rate 20.359229 samp/s throughput 1.96e+08 bytes/s
# zsub://127.0.0.1:7880
# 100 batches, 3200 samples
# 0.0499 s per batch, 0.00156 s per sample
# shapes: {('float16', 32, 224, 224, 3)}
# [0 1] mean=0.446 std=0.279 n=481689600
# rate 20.326072 samp/s throughput 1.96e+08 bytes/s
# zsub://127.0.0.1:7880
# 100 batches, 3200 samples
# 0.0515 s per batch, 0.00161 s per sample
# shapes: {('float16', 32, 224, 224, 3)}
# [0 1] mean=0.446 std=0.279 n=481689600
# rate 19.785719 samp/s throughput 1.91e+08 bytes/s
# zsub://127.0.0.1:7880
# 100 batches, 3200 samples
# ...
